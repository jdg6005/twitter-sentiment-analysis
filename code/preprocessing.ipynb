# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("../data/twitter_training.csv", header=None) # path to data
df.columns = ["id", "entity", "sentiment", "tweet"] # naming columns for easier access
df = df.dropna()
print(df["tweet"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("../data/twitter_training.csv", header=None) # path to data
#       2 df.columns = ["id", "entity", "sentiment", "tweet"] # naming columns for easier access
#       3 df = df.dropna()
#
# NameError: name 'pd' is not defined

# %%
vectorizer = TfidfVectorizer(ngram_range=(2, 2))  
tfidf_matrix = vectorizer.fit_transform(df['tweet'])

# %%
feature_names = vectorizer.get_feature_names_out()
print("Feature Names:", feature_names)
# Out:
# Feature Names: ['00 00' '00 00 on' '00 000' ... 'นจาก playstation' 'นจาก unk' 'ℐℓ٥ ٥υ']
